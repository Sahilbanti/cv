# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahilbanti/cv/blob/main/Map1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Folium if not installed
# !pip install folium

import folium

# Data: Top 20 most visited cities (2023 estimates)
cities = [
    {"name": "Bangkok", "lat": 13.7563, "lon": 100.5018, "rank": 1, "visitors": 22.8},
    {"name": "Paris", "lat": 48.8566, "lon": 2.3522, "rank": 2, "visitors": 19.1},
    {"name": "London", "lat": 51.5074, "lon": -0.1278, "rank": 3, "visitors": 19.0},
    {"name": "Dubai", "lat": 25.276987, "lon": 55.296249, "rank": 4, "visitors": 16.3},
    {"name": "Singapore", "lat": 1.3521, "lon": 103.8198, "rank": 5, "visitors": 14.7},
    {"name": "Kuala Lumpur", "lat": 3.139, "lon": 101.6869, "rank": 6, "visitors": 14.1},
    {"name": "New York", "lat": 40.7128, "lon": -74.0060, "rank": 7, "visitors": 13.6},
    {"name": "Istanbul", "lat": 41.0082, "lon": 28.9784, "rank": 8, "visitors": 13.4},
    {"name": "Tokyo", "lat": 35.6895, "lon": 139.6917, "rank": 9, "visitors": 12.9},
    {"name": "Antalya", "lat": 36.8969, "lon": 30.7133, "rank": 10, "visitors": 12.4},
    {"name": "Seoul", "lat": 37.5665, "lon": 126.9780, "rank": 11, "visitors": 11.3},
    {"name": "Osaka", "lat": 34.6937, "lon": 135.5023, "rank": 12, "visitors": 10.8},
    {"name": "Mecca", "lat": 21.3891, "lon": 39.8579, "rank": 13, "visitors": 10.5},
    {"name": "Pattaya", "lat": 12.9236, "lon": 100.8825, "rank": 14, "visitors": 10.1},
    {"name": "Milan", "lat": 45.4642, "lon": 9.1900, "rank": 15, "visitors": 9.9},
    {"name": "Barcelona", "lat": 41.3874, "lon": 2.1686, "rank": 16, "visitors": 9.1},
    {"name": "Palma de Mallorca", "lat": 39.5696, "lon": 2.6502, "rank": 17, "visitors": 8.9},
    {"name": "Bali", "lat": -8.3405, "lon": 115.0920, "rank": 18, "visitors": 8.3},
    {"name": "Hong Kong", "lat": 22.3193, "lon": 114.1694, "rank": 19, "visitors": 8.1},
    {"name": "Las Vegas", "lat": 36.1699, "lon": -115.1398, "rank": 20, "visitors": 7.8}
]

# Create a map centered around a global point
world_map = folium.Map(location=[20, 0], zoom_start=2)

# Add markers
for city in cities:
    popup_text = f"City: {city['name']}<br>Rank: {city['rank']}<br>Visitors: {city['visitors']}M"
    folium.Marker(
        location=[city["lat"], city["lon"]],
        popup=folium.Popup(popup_text, max_width=300),
        tooltip=city["name"],  # Hover effect
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(world_map)

# Display the map
world_map
# Out:
# ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
